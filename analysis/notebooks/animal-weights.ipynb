# %%
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv('/Users/archydeberker/Downloads/Final_Data_PLOS.csv')

# %%
df['Age (Weeks)'] = df['VISIT_AGE']*52

# %%
breed_1 = df[df['BREED_ID']==1].sample(2000).dropna(how='any')

# %%
px.scatter(breed_1, x='Age (Weeks)', y='WEIGHT', 
          template='plotly_white', opacity=.1)
# Out:
# <div>                            <div id="e285e32e-c45b-4c26-a8df-3a4bd6337d8d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e285e32e-c45b-4c26-a8df-3a4bd6337d8d")) {                    Plotly.newPlot(                        "e285e32e-c45b-4c26-a8df-3a4bd6337d8d",                        [{"hovertemplate": "Age (Weeks)=%{x}<br>WEIGHT=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa", "opacity": 0.1, "symbol": "circle"}, "mode": "markers", "name": "", "showlegend": false, "type": "scattergl", "x": [7.3839999999999995, 15.079999999999998, 14.040000000000001, 38.064, 8.06, 43.524, 12.427999999999999, 21.84, 49.763999999999996, 22.828, 42.172000000000004, 17.524, 51.116, 82.00399999999999, 55.016000000000005, 25.688, 15.6, 21.788,
# ...

# %%
breed_1 = breed_1[breed_1['Age (Weeks)'] < 20]

# %%
breed_1.to_csv('/Users/archydeberker/Desktop/code/good-news-graphs/site/src/data/dog_weights.csv')

# %%
[x  for x in breed_1['WEIGHT'].values]
# Out:
# [21.818,
#  22.407,
#  8.8,
#  19.504,
#  21.137,
#  10.659,
#  22.68,
#  24.675,
#  9.525,
#  6.532,
#  15.105,
#  35.017,
#  10.251,
#  20.049,
#  11.884,
#  24.494,
#  7.439,
#  11.793,
#  7.756,
#  27.715,
#  8.21,
#  15.649,
#  17.781,
#  11.793,
#  7.076,
#  22.498,
#  11.657,
#  21.364,
#  23.133,
#  11.793,
#  9.843,
#  21.319,
#  13.608,
#  17.735,
#  7.257,
#  7.076,
#  8.618,
#  10.886,
#  14.878,
#  17.69,
#  11.839,
#  9.072,
#  24.948,
#  3.402,
#  22.634,
#  7.893,
#  19.504,
#  18.597,
#  21.183,
#  26.49,
#  20.82,
#  28.213,
#  22.317,
#  21.319,
#  9.026,
#  8.074,
#  25.855,
#  26.308,
#  18.869,
#  5.851,
#  19.686,
#  21.5,
#  12.61,
#  24.494,
#  17.962,
#  11.204,
#  11.34,
#  22.77,
#  21.546,
#  33.566,
#  23.814,
#  22.498,
#  24.086,
#  15.921,
#  12.428,
#  8.981,
#  8.845,
#  20.276,
#  14.152,
#  24.857,
#  16.874,
#  10.705,
#  11.34,
#  7.666,
#  21.319,
#  13.154,
#  8.573,
#  13.517,
#  9.752,
#  11.793,
#  7.575,
#  8.255,
#  24.04,
#  22.589,
# ...
